# %% [markdown]
# # Mining Twitter (Based on Chapter 2 of the book 'Mastering...')
#
# In this notebook you will learn the basic concepts of Twitter mining and will try to gather some data from Twitter. Follow the steps, and do the exercises in a copy of this notebook. For that, click in *File -> Make a copy...* button. Don't forget to rename it.
#
# To include a new cell in the notebook, click on the plus sign on the toolbar, or tipe *Alt+Enter* to execute the current cell and create a new one. You can also click on the *Cell* menu.
#
# ## Important
# You have to run all the commands of this document, and make sure that they were executed well. After you finish, you have to save it as PDF and submit. Click in File -> Download as -> PDF via Latex to do so.
#
# **If you don't have Latex at your computer**, simply use File -> Print Preview and generate the PDF from there.

# %% [markdown]
# ## Installing libraries
# If one of the libraries is missing, go to Anaconda, at the Environments tab on the left side of the window and find and install your library.
#
# ![Anaconda](./Pic16.png)

# %% [markdown]
# ## Tweepy, Json and Python
#
# To collect data and make it readable, two libraries will be used. Tweepy is a library that embed the twitter API functions making it easier to interact with the Twitter server.
#
# Json is the format that the data is extracted from Twitter. For this reason, the library Json is also important.

# %% [markdown]
# ## Create your own key at Twitter webpage
# You need your own keys to have access to Twitter API. For that, go to https://apps.twitter.com/ then create a new App, and generate the keys.
#
# In case you have problems, watch the 5 first minutes of https://www.youtube.com/watch?v=pUUxmvvl2FE only. It is more than enough for this task.

# %% [markdown]
# ## Put your keys here!
#
# The variables where you should put your keys are below. So copy and paste all the 4 keys and paste them below.
#
# The first part of this notebook shows you the Tweepy library being loaded, together with the os and sys libraries. Those are used to check files at your system and yield system messages in case it is necessary.
#
# The two functions basically will read your tokens and keys and generate an object that can communicate with Twitter and ask for data. Don't be scared at first moment! Those functions are default for all twitter applications, and are very ugly, indeed.

# %%
import os
import sys
from tweepy import API
from tweepy import OAuthHandler

# %%
def get_twitter_auth():
    """Setup Twitter authentication.

    Return: tweepy.OAuthHandler object
    """
    try:
        consumer_key = 'AlQL8pwAGZOQKt8FyrGXZuQk3'# os.environ['TWITTER_CONSUMER_KEY']
        consumer_secret = 'fwNMZMmOk8GHgySPoUnyWoStTPFjVd2ZSUMmkZ6spo4rBbqG2Z' # os.environ['TWITTER_CONSUMER_SECRET']
        access_token = '40952530-OWYhN5ypDqCDdyu1eHoqLlhLzaYryGrk7Dsd9iX3N' # os.environ['TWITTER_ACCESS_TOKEN']
        access_secret = 'w1FONctgWjDGqHz8Z40YPVOrtY4t9bXlIfJ3d1PcYmbCC' # os.environ['TWITTER_ACCESS_SECRET']
    except KeyError:
        sys.stderr.write("TWITTER_* environment variables not set\n")
        sys.exit(1)    
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    return auth

# %%
def get_twitter_client():
    """Setup Twitter API client.

    Return: tweepy.API object
    """
    auth = get_twitter_auth()
    client = API(auth)
    return client

# %% [markdown]
# ## Getting tweets from your timeline
# So the first thing I'm gonna do is to read my own tweets from my own timeline. For that, I'll use more stuff from Tweepy (the cursor) and also the library Json. The data dumped on us after we request something to Python API is in Json format. If you wanna learn more about that, feel free to enjoy http://www.w3schools.com/js/js_json_intro.asp

# %%
import json
from tweepy import Cursor

# %% [markdown]
# As you can see below there is no need for changes in the code. the client.home_timeline is the query for the Cursor, that will return 200 x 4 = 800 tweets from your home (that is the maximum you can get from your own timeline).
#
# **Notice** that a file named home_timeline.jsonl will be generated on the same folder as you saved this notebook! You can open this file to see a very messy information about all your tweets (one per line).

# %%
client = get_twitter_client()

with open('home_timeline.jsonl', 'w') as f:
    for page in Cursor(client.home_timeline, count=200, include_rts=True).pages(4):
        for status in page:
            # Process a single status
            f.write(json.dumps(status._json, indent=4)+"\n")

# %% [markdown]
# ## Activity 1
#
# Open the file called home_timeline.jsonl and read it. Use a text editor for that, like Gedit (Linux), Notepad (Windows) or TextEdit (Mac OSx).
# 1. What kind of information do you see in the file?
# 2. Can you get your tweets from the file? If yes, how?
# 3. Can you say what is the code doing by just reading the lines?

# %% [markdown]
# ## Getting tweets from another user's timeline
# You can also get information about another user's timeline. And the good news are: you can get more than the 800 tweets you got before! But now you have to give the username of the twitter account you wanna take the tweets. We will read 3200 tweets from VUamsterdam account.

# %%
# Give the name of the account you want to crawl the data from.
user = 'VUamsterdam'
fname = "user_timeline_{}.jsonl".format(user)

# %%
# Collecting 16 pages of 200 tweets each.
with open(fname, 'w') as f:
    for page in Cursor(client.user_timeline, screen_name=user, count=200).pages(16):
        for status in page:
            f.write(json.dumps(status._json)+"\n")

# %% [markdown]
# ## Good to know!
# Using the Cursor to find tweets from your own account gives you a limit of 800 tweets maximum. When you use the second function, finding the tweets in a user timeline, this limit increaes to 3200.
#
# It is also good to know the structure of a tweet. In our code above the *_json* attribute is the one saved in the file. This attribute contains all the information from the tweet in a JSON format. The JSON format is useful to keep the structure of the information to be saved, and it is the same as a dictionary. In our case, we are creating a jsonl file, or a list of jsons, because every line corresponds to the information of a tweet.

# %% [markdown]
# ## Entity Analysis
#
# Now that we can get the tweets in a timeline, we can also extract the hashtags and produce the list with the more common ones.
#
# Remember that you have to change the name of your input (fname) if you are investigating another account!

# %%
from collections import Counter

def get_hashtags(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('hashtags', [])
    return [tag['text'].lower() for tag in hashtags]

# %%
# Read the file saved and extract the hashtags
with open(fname, 'r') as f:
    hashtags = Counter()
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        hashtags.update(hashtags_in_tweet)
    for tag, count in hashtags.most_common(20):
        print("{}: {}".format(tag, count))
# Out:
# wvdw: 89
# vuconferentie: 84
# ech2016: 69
# opendagvu: 56
# vu: 49
# vuevent: 41
# vumag: 40
# vusymposium: 27
# oaj16: 22
# vulezing: 19
# vumasters: 18
# vusustainable: 17
# zwaartekrachtsgolven: 16
# vumasterdag: 16
# vufestival: 15
# oaj: 15
# vukabinet: 14
# icc: 13
# amsterdam: 13
# diesvu: 12

# %% [markdown]
# ## Question about your data set:
# 1. Do you have any insight by looking at the hashtags found in the page you are verifying? Can you explain why those hashtags are the most used?

# %% [markdown]
# ### Going deeper...
#
# We can have deeper analysis of the statistics of the hashtags, instead of a simple counting of the number of times each one is used.

# %%
from collections import defaultdict

with open(fname, 'r') as f:
    hashtag_count = defaultdict(int)
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        n_of_hashtags = len(hashtags_in_tweet)
        hashtag_count[n_of_hashtags] += 1

    tweets_with_hashtags = sum([count for n_of_tags, count in hashtag_count.items() if n_of_tags > 0])
    tweets_no_hashtags = hashtag_count[0]
    tweets_total = tweets_no_hashtags + tweets_with_hashtags
    # print tweets_total
    tweets_with_hashtags_percent = '{:2f}'.format(tweets_with_hashtags * 100.0 / tweets_total )
    tweets_no_hashtags_percent = "{:2f}".format(tweets_no_hashtags * 100.0 / tweets_total )
    # print tweets_no_hashtags_percent
    print("{0} tweets without hashtags ({1}%)".format(tweets_no_hashtags, tweets_no_hashtags_percent))
    print("{} tweets with at least one hashtag ({}%)".format(tweets_with_hashtags, tweets_with_hashtags_percent))

    for tag_count, tweet_count in hashtag_count.items():
        if tag_count > 0:
            percent_total = "%.2f" % float(tweet_count * 100.0 / tweets_total )
            percent_elite = "%.2f" % float(tweet_count * 100.0 / tweets_with_hashtags)
            print("{} tweets with {} hashtags ({}% total, {}% elite)".format(tweet_count,
                                                                             tag_count,
                                                                             percent_total,
                                                                             percent_elite))
# Out:
# 1916 tweets without hashtags (59.893717%)
# 1283 tweets with at least one hashtag (40.106283%)
# 975 tweets with 1 hashtags (30.48% total, 75.99% elite)
# 226 tweets with 2 hashtags (7.06% total, 17.61% elite)
# 49 tweets with 3 hashtags (1.53% total, 3.82% elite)
# 23 tweets with 4 hashtags (0.72% total, 1.79% elite)
# 8 tweets with 5 hashtags (0.25% total, 0.62% elite)
# 2 tweets with 6 hashtags (0.06% total, 0.16% elite)

# %% [markdown]
# ## User mentions on tweets
#
# In a similar way we can see user mentions

# %%
def get_mentions(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('user_mentions', [])
    return [tag['screen_name'] for tag in hashtags]

# %%
with open(fname, 'r') as f:
    users = Counter()
    for line in f:
        tweet = json.loads(line)
        mentions_in_tweet = get_mentions(tweet)
        users.update(mentions_in_tweet)
    for user, count in users.most_common(20):
        print("{}: {}".format(user, count))
# Out:
# VUamsterdam: 935
# VU_Science: 217
# VU_FGB: 201
# VU_law: 138
# advalvas_vu: 101
# FGWVU: 96
# VUalumnus: 93
# FSW_VU: 81
# MarjoleinJanse1: 76
# mariekedehoon: 63
# VUmcAmsterdam: 58
# VU_FBW: 55
# VU_Criminologie: 53
# parool: 51
# NPORadio1: 50
# Godgeleerdheid: 48
# markvanvugt1: 46
# vinsub: 45
# UniversiteitNL: 42
# volkskrant: 39

# %% [markdown]
# ## Tokenization and Text Analysis
# Now we are gonna read the text of the tweets and process some of the words, checking some statistics also. For this we will use the NLTK library.

# %% [markdown]
# #### In case you have a problem like the one below, uncomment the following lines:
# ![./Problem01.png](./Problem01.png)
#
# ![./Problem01.png](./Solution01.png)

# %% [markdown]
# NLTK will be our Natural Language Library! You have to install it (possibly) to make the code work. So uncomment the code below if necessary, and after you install it, then comment it again.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import string

# %%
def process(text, tokenizer=TweetTokenizer(), stopwords=[]):
    """Process the text of a tweet:
    - Lowercase
    - Tokenize
    - Stopword removal
    - Digits removal

    Return: list of strings
    """
    text = text.lower()
    tokens = tokenizer.tokenize(text)
    
    # If we want to normalize contraction, uncomment this
    tokens = normalize_contractions(tokens)
    return [tok for tok in tokens if tok not in stopwords and not tok.isdigit() and tok != u'\u2026']

# %%
def normalize_contractions(tokens):
    """Example of normalization for English contractions.

    Return: generator
    """
    token_map = {
        "i'm": "i am",
        "you're": "you are",
        "it's": "it is",
        "we're": "we are",
        "we'll": "we will",
    }
    for tok in tokens:
        if tok in token_map.keys():
            for item in token_map[tok].split():
                yield item
        else:
            yield tok

# %%
tweet_tokenizer = TweetTokenizer()

punct = list(string.punctuation)
stopword_list = stopwords.words('dutch') + punct + ['rt', 'via'] 

tf = Counter()
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = process(text=tweet.get('text', ''),
                         tokenizer=tweet_tokenizer,
                         stopwords=stopword_list)
        tf.update(tokens)
    for tag, count in tf.most_common(30):
        print("\'{}\': {}".format(tag.encode('utf-8'), count))
# Out:
# '@vuamsterdam': 946
# 'vu': 302
# '@vu_science': 217
# 'https': 206
# '@vu_fgb': 202
# 'the': 194
# 'onderzoek': 148
# 'vu-hoogleraar': 147
# 'we': 142
# 'kom': 139
# '@vu_law': 138
# 'nieuwe': 123
# 'tijdens': 113
# 'vandaag': 111
# '’': 111
# 'https://t.…': 107
# '@advalvas_vu': 101
# 'onze': 99
# 'a': 98
# '@fgwvu': 96
# 'vanavond': 95
# 'studenten': 95
# 'https://t.c…': 93
# '@vualumnus': 93
# 'to': 92
# '#wvdw': 90
# 'https://t.co…': 87
# '#vuconferentie': 85
# 'hoogleraar': 84
# 'amsterdam': 83

# %% [markdown]
# ### Plotting frequency
#
# Instead of printing the values of frequency we can create graphics that allow us to visualize the results better.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

tweet_tokenizer = TweetTokenizer()
punct = list(string.punctuation)
stopword_list = stopwords.words('dutch') + punct + ['rt', 'via']


tf = Counter()
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = process(text=tweet.get('text', ''),
                         tokenizer=tweet_tokenizer,
                         stopwords=stopword_list)
        tf.update(tokens)
        
    tags = [tag for tag, count in tf.most_common(30)]
    
    #print tags
    y = [count for tag, count in tf.most_common(30)]
    x = range(1, len(y)+1)

    plt.figure(figsize=(14,7), dpi=300)

    plt.bar(x, y, align='center', alpha=0.5)
    plt.title("Term Frequencies")
    plt.ylabel("Frequency")
    plt.xticks(range(1,len(tags)+1), tags, rotation=90)
    plt.savefig('term_distribution.png')

# %%
### The same can be done for the hashtags

# %%
def get_hashtags(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('hashtags', [])
    return [tag['text'].lower() for tag in hashtags]

fname = 'user_timeline_VUamsterdam.jsonl'
with open(fname, 'r') as f:
    hashtags = Counter()
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        hashtags.update(hashtags_in_tweet)
    for tag, count in hashtags.most_common(30):
        print("{}: {}".format(tag, count))

    tags = [tag for tag, count in hashtags.most_common(30)]
    
    #print tags
    y = [count for tag, count in hashtags.most_common(30)]
    x = range(1, len(y)+1)

    plt.figure(figsize=(14,7), dpi=300)

    plt.bar(x, y, align='center', alpha=0.5)
    plt.title("Hashtags Frequencies")
    plt.ylabel("Frequency")
    plt.xticks(range(1,len(tags)+1), tags, rotation=90)
    plt.savefig('hashtags_distribution.png')
# Out:
# wvdw: 89
# vuconferentie: 84
# ech2016: 69
# opendagvu: 56
# vu: 49
# vuevent: 41
# vumag: 40
# vusymposium: 27
# oaj16: 22
# vulezing: 19
# vumasters: 18
# vusustainable: 17
# zwaartekrachtsgolven: 16
# vumasterdag: 16
# vufestival: 15
# oaj: 15
# vukabinet: 14
# icc: 13
# amsterdam: 13
# diesvu: 12
# vuamsterdam: 12
# rio2016: 12
# ontheroofff: 11
# ll17: 11
# mh17: 10
# criminologie: 10
# terugkijktip: 10
# vrijheidsmaaltijd: 10
# aardwetenschappen: 9
# oaj17: 9

# %% [markdown]
# ## Activity 2
# You might have run the code up to now based on the original example of the VU Amsterdam profile. Pick a new profile on Twitter and run the first part again. Also change the code above to show the 1000 most common hashtags.
#
# Can you tell about the results you obtained?
# 1. Why did you pick this page?
# 2. What is interesting about it when you verify the hashtags and the most common words?
# 3. What else would be interesting to do with the data obtained in this data set?

# %% [markdown]
# # Streaming
# Streaming is a way to keep a 'door' open listening to the twitter flow of interactions over time. This allow us to collect more data than permited with all the restrictions of the API.

# %%
import string
import time
from tweepy import Stream
from tweepy.streaming import StreamListener

# %%
def format_filename(fname):
    """Convert fname into a safe string for a file name.

    Return: string
    """
    return ''.join(convert_valid(one_char) for one_char in fname)

# %%
def convert_valid(one_char):
    """Convert a character into '_' if "invalid".

    Return: string
    """
    valid_chars = "-_.%s%s" % (string.ascii_letters, string.digits)
    if one_char in valid_chars:
        return one_char
    else:
        return '_'

# %%
class CustomListener(StreamListener):
    """Custom StreamListener for streaming Twitter data."""

    def __init__(self, fname):
        safe_fname = format_filename(fname)
        self.outfile = "stream_%s.jsonl" % safe_fname

    def on_data(self, data):
        try:
            with open(self.outfile, 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            sys.stderr.write("Error on_data: {}\n".format(e))
            time.sleep(5)
        return True

    def on_error(self, status):
        if status == 420:
            sys.stderr.write("Rate limit exceeded\n".format(status))
            return False
        else:
            sys.stderr.write("Error {}\n".format(status))
            return True

# %% [markdown]
# The **stream** will run for 120 seconds and the query is Ajax OR footbal. If you want the occurrence of two values together, like Ajax AND football, we should pass the query = ['Ajax footbal']

# %%
query = ['Ajax', 'football']
query_fname = ' '.join(query) # string
auth = get_twitter_auth()
twitter_stream = Stream(auth, CustomListener(query_fname))
twitter_stream.filter(track=query, async=True)
time.sleep(120)
# TO stop your streaming...
twitter_stream.running = False

# %%
# To stop your streaming before the time set...
twitter_stream.running = False

# %% [markdown]
# ## Activity 3
#
# Now, create your own query, and pay attention on where are the results of the query being saved. Can you tell just looking at the code?
#
# Choose your query with wisdom, 'cause you are going to use it next. You can also increase the time if you want to capture more tweets.

# %% [markdown]
# # Sentiment Analysis of the Tweets
#
# Change the file to your stream file in order to get the right dataset.

# %%
from unidecode import unidecode
tweets = []
text_tweets = []
fileTweets = "stream_Ajax_football.jsonl"
print fileTweets
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        #print tweet
        try:
            aux = { "text" : unidecode(tweet['text'].replace('"','')), "language": tweet['lang'],  "query" : query, "id" : tweet['id'] }
            text_tweets.append(tweet['text'])
            tweets.append(aux)
        except:
            print 'no text', tweet
# Out:
# stream_Ajax_football.jsonl

# %%
len(tweets)
# Out:
# 3199

# %%
tweets[7]
# Out:
# {'id': 930139677222457344,
#  'language': u'en',
#  'query': ['Ajax', 'football'],
#  'text': 'RT @Jos__A: Our class of 2016-2017 has officially graduated! Congratulations with your MSc in Business Administration - #HRM! @VU_SBE @VUam...'}

# %%
result = { "data" : tweets }

# %%
def parse_response(json_response):
    negative_tweets, positive_tweets = 0, 0
    for j in json_response["data"]:
        if int(j["polarity"]) == 0:
            negative_tweets += 1
        elif int(j["polarity"]) == 4:
            positive_tweets += 1
    return negative_tweets, positive_tweets

# %%
import urllib2
URL_SENTIMENT140 = "http://www.sentiment140.com/api/bulkClassifyJson"
req = urllib2.Request(URL_SENTIMENT140)
req.add_header('Content-Type', 'application/json')
response = urllib2.urlopen(req, str(result))
json_response = json.loads(response.read())
negative_tweets, positive_tweets = parse_response(json_response)

print "Positive Tweets: " + str(positive_tweets)
print "Negative Tweets: " + str(negative_tweets)
# Out:
# Positive Tweets: 884
# Negative Tweets: 1

# %% [markdown]
# ## Activity 4
#
# 1. Print a list of 5 positive and 5 negative tweets using the positive_tweets and negative_tweets list. (the responses are in the variable json_response)
# 2. Can you draw any hypotheses over why did you get this proportion of positive/negative tweets?

# %%
json_response
# Out:
# {u'data': [{u'id': 931048310848348160,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @vinsub: Vijf topopleidingen @VUamsterdam in Keuzegids Universiteiten 2018! Trots op!'},
#   {u'id': 930851280548966400,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @FGWVU: NIEUWS: Bachelor opleidingen Philosophy, Poltics &amp; Economics (PPE) en Griekse en Latijnse Taal en Cultuur (GLTC) van @FGWVU zijn...'},
#   {u'id': 930850022819844097,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Trots! Onze bachelors Aardwetenschappen en Biologie zijn beiden beoordeeld als topopleiding! https://t.co/Ntx1ADvPT7  #Topo...'},
#   {u'id': 930750009846456320,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'De beste universiteit van Amsterdam vind je aan de ring! https://t.co/K7kz58jmVD #keuzegids https://t.co/ZebqHHmwQ9'},
#   {u'id': 930741044634902528,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Hoe maken we nieuwe connecties in het #debat? Kom op 29 nov naar Recht van Spreken. Kijk hier de video van 2016... https://t.co/LjebpVJdzF'},
#   {u'id': 930706254309281792,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT

#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @CyCriminologist: Neemt #cybercrime toe? Check voor het antwoord op deze criminologische vraag deze #nrccheckt in @nrc  @VU_Criminologie...'},
#   {u'id': 926113474509524994,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @FGWVU: KIJKTIP: VU-geurhistoricus @caroverbeek maakt de geur van de kleedkamer van het voetbalelftal dat het EK in '88 won: https://t.c..."},
#   {u'id': 926054870322438144,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Vertrouwen van lager opgeleiden in rechtspraak nog lager dan gedacht blijkt uit VU-promotieonderzoek. https://t.co/3LdfdF3Rij #BNR'},
#   {u'id': 926048619559612418,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VUalumnus: College alumnus Wouter Bos @VUamsterdam over populisme: geen reden tot paniek, wel gevaar. En oplossingen. #VUmag https://t....'},
#   {u'id': 925792694194069504,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_law: Simpele checklist volstaat niet om risico van recidive vast te stellen. Joke Harte in @volkskrant https://t.co/3gfz30mnN6'},
#   {u'id': 925762710830272512,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @Micropia: Vrijdag is prof. dr. ir. Remco Kort officieel aangesteld als Micropia-hoogleraar verbonden aan de @VUamsterdam. https://t.co/...'},
#   {u'id': 925740329055244288,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'@BeautyB_nl Dag Celine, De data voor de opleidingen die in februari/maart proefstuderen organiseren volgen later dit jaar.'},
#   {u'id': 925736862190358528,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'https://t.co/CSLT22Y3nm Hoe kan het #maatschappelijk #debat anders? Kom op 29 nov naar Recht van Spreken.... https://t.co/exAMpwhvAt'},
#   {u'id': 925695329533644803,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Fill in the International Student Barometer! International students keep an eye on your email inbox! #VUstudentbarometer'},
#   {u'id': 925671854563524608,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @VU_Science: Nico van Straalen neemt afscheid en kijkt terug: 'Ik doe graag rare dingen tijdens colleges' https://t.co/3kVyIfUxg0 https:..."},
#   {u'id': 925665202225471489,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @Godgeleerdheid: INTERVIEW: met VU-hoogleraar Wido van Peursen in het @refdag over 40 jaar Eep Talstra Centre for Bible and Computer: ht...'},
#   {u'id': 925405719653994496,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @AMS_DataSci: We are nominated as ICT Educator of the Year @computablenl #ComputableAwards Tonight! @VUamsterdam @VU_Science @UvA_Amster...'},
#   {u'id': 925338837089488896,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @VU_Criminologie: @HarteJoke @VUamsterdam in @volkskrant over risicotaxatie als te simplistische 'oplossing' voor recidivepredictie:\n\nht..."},
#   {u'id': 925337505209245696,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Nederland heeft een veel te klein budget voor cybersecurity onderzoek zegt Herbert Bos bij De Ochtendspits van @BNR https:/...'},
#   {u'id': 925292285616640000,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: NIEUWS Rechtshandige honkballers succesvoller als ze linkshandig slaan. Onderzoek @david_l_mann #WorldSeriesBaseball https://t....'},
#   {u'id': 925278390550257664,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Criminologie: In @EenVandaag Jasper van der Kemp @VU_law @VUamsterdam over de Cold Case zaak van Miriam Sharon.\n\nhttps://t.co/WK84mn...'},
#   {u'id': 925039129980801024,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VUalumnus: Een dag uit het leven van alumna Milou Halbesma: Directeur Publiekszaken bij @vangoghmuseum @VU_SBE @VUamsterdam https://t.c...'},
#   {u'id': 925030583310454785,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @ConGenAMS: Business students from @VUamsterdam hear from experts about opportunities in the field of #cybersecurity and the risks of ou...'},
#   {u'id': 924948857074700288,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @

#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @FSW_VU: Maatschappelijke diensttijd niet verplicht in Rutte III, @renebekkers ligt 'gemiste kans' toe bij @RTLnieuws : https://t.co/YMY..."},
#   {u'id': 922161975622332416,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"'Weg met handelsbarrieres voor Afrika en Azie, en met topsectorenbeleid' -Minister Martin van Hees #VUkabinet... https://t.co/efqVPVeb2x"},
#   {u'id': 921648616372137984,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"'Een begroting die tegen een stootje kan. Dat is sociale zekerheid' -Minister Arjen Siegmann #VUkabinet... https://t.co/RMQetWOK6s"},
#   {u'id': 921371837283688449,
#    u'language': u"u'en'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Pieter van Beukering calling for ideas to improve the level of sustainability @VUamsterdam #sustainableminds https://t.co/c...'},
#   {u'id': 921367876250079232,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Kan de VU duurzamer? En wat kan jij doen? Laat het ons weten #sustainableminds https://t.co/lqaQEQnikL https://t.co/M3hWLS6vWL'},
#   {u'id': 921359488401248256,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @MarcSchuilen: Interview vandaag in @zorgenwelzijn: Meer aandacht nodig voor positieve veiligheid in de wijk. #positivecriminology https...'},
#   {u'id': 921355442789462016,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Vrije Schrijver@BJHeijne gaat straks in gesprek met @LiekeMarsman en @Roos01 over de taal van het duurzaamheidsdeba... https://t.co/zodztYnM9D'},
#   {u'id': 921286564944244736,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: In september 2018 start de nieuwe onderzoeksmaster Genes in Behaviour and Health @VUAmsterdam! https://t.co/Fwb7NVRPBi https://...'},
#   {u'id': 921258568552189952,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"'Belasting op CO2-uitstoot en steun voor groene ondernemers' -Minister Pieter van Beukering #VUkabinet... https://t.co/9a0qRkQTml"},
#   {u'id': 920950377637466112,
#    u'language': u"u'en'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Community Service Learning is actueel https://t.co/JttotIcdBx Professor Robert Bringle  spreekt erover op 20-10... https://t.co/sl07YrzQ1Q'},
#   {u'id': 920916185432158208,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @JelleJolles: Aanbevelingen voor de nieuwe ministers van onderwijs: stimuleer ontplooiing, kennis, kansen en dialoog: https://t.co/5UU5D...'},
#   {u'id': 920901239566753792,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"'Begeleiding bij afvallen en een taks op zoete dranken' -Minister Ingrid Steenhuis #VUkabinet... https://t.co/E9MDyWuCEO"},
#   {u'id': 920706022133714945,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @raymondgradus: '4000 euro per jaar voor iedereen die actief bijdraagt' - VU Magazine https://t.co/Gpu7zccpcX"},
#   {u'id': 920650716619902976,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @mariekedehoon: Tadaaa! Ik ben Minister van Defensie geworden  Supergrappig initiatief van @VUamsterdam, met natuurlijk ook een serieuz...'},
#   {u'id': 920624339074060288,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'@liekemarsman schreef  over liefde en klimaatverandering  https://t.co/3euKxIlRNB  Ze gaat in gesprek met @Bjheijne... https://t.co/hzsTU4Lkbr'},
#   {u'id': 920615542498775040,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Het regeerakkoord is klaar. Maar hoe moet het nou echt in Nederland? Dat weet het #VUkabinet.... https://t.co/FBy3siMP4N'},
#   {u'id': 920250970822594561,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @vinsub: Minister Bussemaker in gesprek met studenten @VUamsterdam lancering #OPeRA https://t.co/zLXxZMN5Za'},
#   {u'id': 919948470995292160,
#    u'language': u"u'und'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'#trots https://t.co/EvzvmQyssM'},
#   {u'id': 919948113548324864,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Wetenschappers vinden sterrenbotsing en goud met #zwaartekrachtsgolven https://t.co/SBQZErIPMk @VU_Science https://t.co/T1QZ2iHHrE'},
#   {u'id': 919943263389388800,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @NWONieuws: Wetenschappelijke doorbraak: LIGO &amp; Virgo detecteren eerste zwaartekrachtgolven van samensmeltende neutronensterren: https:/...'},
#   {u'id': 918780041575661568,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"Benieuwd naar de video en foto's van ons VU/VUmc-Weekend van de Wetenschap afgelopen zaterdag 7 oktober? Zie  https://t.co/cZ6oWP4a2e"},
#   {u'id': 918507928377839619,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'#diesVU De VU is jarig op 20 oktober. Rapper en VU-student Ferdous Arachid treedt op https://t.co/tbMZog8RU5  check https://t.co/Y7t4kYOYfp'},
#   {u'id': 918477998382309376,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @MarcSchuilen: Hier mijn column in @nrc waarom een #sleepnet niet werkt. En waarom referendum over de #sleepwet onzin is. #WIV  https://...'},
#   {u'id': 918061731657715714,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @advalvas_vu: Gefeliciteerd, @GreenOfficeVU . En vanaf vandaag is Advalvas 100% klimaatneutraal gedrukt! https://t.co/eu402AD3ai https:/...'},
#   {u'id': 918061595821068288,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @AndreaBMaier: Behandeling spierarmoede bij ouderen blijft uit! Luister @BNR 17.20uur. Onderzoek @VUamsterdam: kennis+samenwerking zorgv...'},
#   {u'id': 918033552503164930,
#    u'language': u"u'en'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @P_Pattberg: Looking forward to Pieter's talk and the opportunity work with him as part of the new Sustainability Team! https://t.co/8ju..."},
#   {u'id': 917826204723503104,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Hoe draag jij bij aan een duurzame universiteit? Vrijdag 20 oktober spreekt Pieter van Beukering tijdens de Dies -... https://t.co/KhnfIciwB9'},
#   {u'id': 917747167850303489,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Onze hoogleraar @jwerisman staat in de #duurzame100 van @trouw https://t.co/W1SJeroT0s'},
#   {u'id': 917709784979267585,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: Interesse in Forensische Neuropsychologie en Neuropsychiatrie? Kom 19/10 naar de informatiebijeenkomst @VUamsterdam https://t.c...'},
#   {u'id': 917669150713176064,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @MarjoleinJanse1: Sustainability week @VUamsterdam together with @GreenOfficeVU and celebraties their birthday. Time to act &amp; realize th...'},
#   {u'id': 917668323067879424,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'@RiemkeLevie Dag Riemke, Neem contact op met FCO servicedesk via 020 59 85777.'},
#   {u'id': 917651525324943360,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VUalumnus: Kunstmest is erger dan klimaatverandering #DvdD17 Minderen kan alleen als we anders gaan eten. #VUmag @VUamsterdam https://t...'},
#   {u'id': 917463589417619456,
#    u'language': u"u'en'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_SBE: Congratulations @MJvandenAssem and @dvdolder, co-authors #NobelPrize in #Economics winner prof. Richard H. Thaler! https://t.co...'},
#   {u'id': 917387506710171650,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FBW: Schaatsseizoen begonnen. Interview met #bewegingswetenschapper Jos de Koning @VU_FGB @VUamsterdam over klapschaats https://t.co...'},
#   {u'id': 917358677904027649,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: NIEUWS: VU-hoogleraar Andrea Maier luidt de noodklok: "De behandeling van spierarmoede bij ouderen blijft uit: https://t.co/Vq...'},
#   {u'id': 917358555837222912,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Terugluisteren: Natuurkundige Vasilis Syropoulos over pinguins en antimaterie bij @BNRWetenschap: https://t.co/NWAtQKfgB1'},
#   {u'id': 916969818384936960,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @UAFnl: Om 20 u vertelt arts Shakiba Babri haar verhaal @NPORadio2. Gisteren won ze UAF-Award. https://t.co/LXUnvWOwo2 #vluchtelingen @V...'},
#   {u'id': 916701770444951552,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @HPTDelft: Yesterday officially honored by Jaap Winter, the rector of the @VUamsterdam. With pride we look back at a great year and an e...'},
#   {u'id': 916690805598965760,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @vinsub: Dank aan alle collega's en studenten @VUamsterdam die bijgedragen hebben aan een geslaagde open dag #WvdW. Trots op jullie!"},
#   {u'id': 916680013352656896,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Mede namens Zora, bedankt voor jullie komst naar #WvdW! We hopen dat jullie leuke dag hebben gehad. Hopelijk tot vo... https://t.co/EQGXIw3hX9'},
#   {u'id': 916673157293072384,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @Godgeleerdheid: VU-docent Annette Mosher vertelt hoe Native Americans over de natuur, het klimaat en spiritualiteit denken @VUamsterdam...'},
#   {u'id': 916671632365760512,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: Bij VU-onderzoeker Katinka vd Kooij een motivatie test om virtuele papieren surprises (Pinatas) kapot te slaan #WvdV #bewegings...'},
#   {u'id': 916670066149789698,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @VU_law: 'Winning isn't everything, its the only thing' @Molfers geeft workshop leiderschap #WvdW https://t.co/q9dNFEjRYI"},
#   {u'id': 916666615609077760,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: Bij VU-onderzoeker Tara Donker krijgen de jonge bezoekers een Virtual Reality cursus voor hoogtevrees! #WvdW @VUamsterdam #psyc...'},
#   {u'id': 916665135523139584,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"Ga als archeoloog aan de slag bij 'Van schatgraver tot archeoloog'  tijdens #wvdw. https://t.co/4lLdhpIatb"},
#   {u'id': 916660287276748800,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: Het @NTR_VU Tweelingen Register is ook aanwezig op het Weekend van @Wetenschap_NL @VUamsterdam. Hoe gezond ben jij? Doe de test...'},
#   {u'id': 916652374609092608,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Hoe gezond is jouw schoollunch? Doe mee aan het onderzoek tijdens #wvdw @VUamsterdam @VUmcAmsterdam https://t.co/neWGvAGNKV'},
#   {u'id': 916649253426073600,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @FGWVU: Veel publiek bij de 'Botten komen tot leven workshop'. Wat kunnen botten ons vertellen over wat mensen vroeger aten? #humanites..."},
#   {u'id': 916646060185006080,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @FGWVU: Hesjes aan, en aan de slag in de 'van schatgraver tot archeoloog' workshop tijdens het Weekend van @Wetenschap_NL @VUamsterdam!..."},
#   {u'id': 916641688537436163,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @vinsub: En daar is ze... geweldige lezing over T. rex Trix door Anne Schulp @VUamsterdam #WvdW backstage bij de VU https://t.co/VjD8cpc...'},
#   {u'id': 916638502779056133,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VUmcAmsterdam: Vandaag worden onze artsen in het simulatielab goed geholpen! #WvdW https://t.co/8KL4ptzXYe'},
#   {u'id': 916636789774962688,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Overstromingen, hoe kan je ze voorkomen? Leer hoe je droge voeten kan houden @VU_Science  tijdens #WvdW... https://t.co/mY3B6AhCWm'},
#   {u'id': 916635265338368000,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @vinsub: Volle bak voor T. rex met Anne Schulp @VUamsterdam #WvdW standing room only! Backstage bij de VU https://t.co/vMgGIGMAvc'},
#   {u'id': 916635036023181312,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB
",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @icroy: The #smell of Waterloo (or Napoleon), smelled live @VUamsterdam @caroverbeek @laurajspeed https://t.co/qCcqPYENn2'},
#   {u'id': 835132294985809924,
#    u'language': u"u'en'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @FlipseAb: Wende Wallert @UBVU en Caro Verbeek @FGWVU start of the Aromatic Art symposium &amp; exhibition @VUamsterdam https://t.co/Ckjzcbk...'},
#   {u'id': 835132162588434432,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @merpeltje: Always interesting stuff happening at @VUamsterdam https://t.co/dSGW52iYGX'},
#   {u'id': 835118301747494912,
#    u'language': u"u'en'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @dvandokkum: Getting ready for the Aromatic Art symposium @VUamsterdam @FGWVU @ChaarlotteEvans https://t.co/CQog6os6wq'},
#   {u'id': 835107351241842689,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @advalvas_vu: Hoe ruikt de maan? Ontdek het zelf. https://t.co/2bpyAv1NeI https://t.co/WiVUDlAzM7'},
#   {u'id': 835093247013896192,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FBW: Morgen 19.00 in @kassa_vara @RoerdinkMelvyn en @VanaHutter @VUamsterdam @VU_FGB  @trapplaus over #traplopen #bewegen https://t....'},
#   {u'id': 835032200479391744,
#    u'language': u"u'und'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @markvanvugt1: @VUamsterdam @ZijlstraCenter https://t.co/FTgCJJtTsV'},
#   {u'id': 835032042832343041,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FBW: Vandaag promotie #bewegingswetenschapper @VUamsterdam @VUmcAmsterdam Suzanne Merkus over Herstellen na nachtdienst  https://t.c...'},
#   {u'id': 835026605722468352,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FBW: Gisterochtend Tom Stevens  @tgastevens @VUamsterdam op @NPORadio1   gemist? Luister terug vanaf minuut 54 https://t.co/Hc...'},
#   {u'id': 834768513642426369,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @LeonieHeres: Hgl Huberts @FSW_VU: er moet weer meer gerichte aandacht en leiderschap #integriteit komen bij de politie https://t.co/51q...'},
#   {u'id': 834753565914779653,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Wat hebben #wiskunde en #DNA-onderzoek met elkaar te maken? #Oratie bijzonder hoogleraar Klaas Slooten: https://t.co/gxMo6r...'},
#   {u'id': 834752646124670976,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Kiezers zijn eenkenniger bij lijsttrekkers dan bij partijstandpunten, blijkt uit VU-onderzoek #TK17 https://t.co/055mwwywm4'},
#   {u'id': 834723049085734913,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @thecatseye: &amp; vanmiddag meer tijdens openbare debatmiddag integriteit: https://t.co/VXT6NRjSPb  georganiseerd @Vrij_Nederland, @Erasmus...'},
#   {u'id': 834695582887342080,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @FEWEB_VU: 'Afkoop erfpacht riskant voor huiseigenaar', zegt hoogleraar Pieter Gautier @pietgautier #erfpacht via @dft https://t.co/YGWF..."},
#   {u'id': 834695574268084224,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Leuk: uitzending vanavond van @hetklokhuis over zwaartekrachtsgolven! @_nikhef @antracom https://t.co/7KTSsxs4Zy'},
#   {u'id': 834694078449254401,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'VU-wetenschappers Aysem Mert, Tibor Bosse, Paul van Lange, Mark van Vught:  Hoe zou u de democratie verbeteren? https://t.co/QyqYc3SXoe'},
#   {u'id': 834687516225761284,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u"RT @AT5: VU-debat moet meer studenten naar stembus lokken: 'Sommigen vergaten te stemmen' https://t.co/VFRG43GiJU https://t.co/84cQz09Igv"},
#   {u'id': 834431757797715969,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Volle bak bij #Aureus debat politici onder 30 jr in Auditorium #VU. Hoezo jonge generatie geen interesse in verkiez... https://t.co/uplfNnehsk'},
#   {u'id': 834420656641028096,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Kijktip: vanavond in #Nieuwsuur, 22.00 uur NPO2: Leo Huberts (#VU Bestuurskunde) over jaarlijks onderzoek integriteit politieke partijen.'},
#   {u'id': 834403758884913152,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Straks bij @eenvandaag: VU-hoogleraar Leo Huberts over jaarlijks integriteitsonderzoek onder politici, de Politieke... https://t.co/Bn9vDngT8f'},
#   {u'id': 834054995871924225,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: VIDEO: Lekenpraatje promotie Carlijn Bergwerff - ADHD-behandeling met voeddingssuplementen niet effectief: https://t.co/zEqtvm9...'},
#   {u'id': 834054963475120128,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_FGB: VIDEO: Lekenpraatje promotie Zoi Manesi - Het effect van oogafbeeldingen nader onderzocht: https://t.co/QaLiSk3DN2'},
#   {u'id': 834023041860501505,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @advalvas_vu: Ernest vd Kwast als gastredacteur, dan krijg je natuurlijk een themanummer over moeders. Met J.M. Coetzee https://t.co/epF...'},
#   {u'id': 833992540042969094,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Evolueert de mens nog? Het nieuwe boek van VU-ecologen Nico van Straalen en Dick Roelofs gaat in op deze vraag: https://t.c...'},
#   {u'id': 833979826209955840,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'Schrijf een ode aan je moeder en win kaartjes en gesigneerd boek Mama Tandoori van Ernest van der Kwast #VUfestival https://t.co/XpwDAaYyk1'},
#   {u'id': 833701647704588290,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_Science: Terugkijktip: Gezondheidseconoom Xander Koolman laat in Nieuwsuur zien dat betere ouderenzorg mogelijk is (op 20:00) https:...'},
#   {u'id': 833696338198007810,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @FGWVU: INTERVIEW: met Jos van Beurden @nrc die promoveerde op teruggavebeleid van Europese landen m.b.t koloniale objecten: https://t.c...'},
#   {u'id': 833696238503600131,
#    u'language': u"u'nl'",
#    u'meta': {u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @VU_law: Straks in @AT5 Nieuws: Jasper van der Kemp @VU_Criminologie over politiebureaus'},
#   {u'id': 833688330961305603,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 4,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @FGWVU: TERUGLUISTEREN: VU-onderzoeker Caro Verbeek bij de @nieuwsshow op @NPORadio1 over wat geuren met je kunnen doen: https://t.co/9O...'},
#   {u'id': 833624976716611584,
#    u'language': u"u'nl'",
#    u'meta': {u'headline': True, u'language': u'en'},
#    u'polarity': 2,
#    u'query': [u'Ajax', u'football'],
#    u'text': u'RT @UBVU: Eerste studenten genieten van muffin en nieuwe #studiezaal 13e etage hoofdgebouw. Kom ook! Er zijn nog #muffins! https://t.co/XBU...'},
#   ...]}

# %% [markdown]
# # [Extra] Time Series Analysis
# **If you have time, and wanna learn more about time series analysis, leave your stream running longer (for one hour or two, for instance) and try the code below. From this part on won't be graded!**
#
# The time series analysis evaluates the tweets over time, giving us an idea about how many tweets were collected every minute. Remember to change the name of fname in case you changed your query.

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
import numpy as np
import pickle

# %%
fname = 'stream_Ajax_football.jsonl'

with open(fname, 'r') as f:
    all_dates = []
    for line in f:
        tweet = json.loads(line)
        all_dates.append(tweet.get('created_at'))

# %%
ones = np.ones(len(all_dates))
idx = pd.DatetimeIndex(all_dates)
# the actual series (at series of 1s for the moment)
my_series = pd.Series(ones, index=idx)

# %%
# Resampling / bucketing into 1-minute buckets
per_minute = my_series.resample('1Min').sum().fillna(0)
print(my_series.head())
print(per_minute.head(30))
# Out:
# 2017-11-16 15:40:32    1.0
# 2017-11-16 15:40:33    1.0
# 2017-11-16 15:40:34    1.0
# 2017-11-16 15:40:34    1.0
# 2017-11-16 15:40:34    1.0
# dtype: float64
# 2017-11-16 15:40:00    128.0
# 2017-11-16 15:41:00    238.0
# 2017-11-16 15:42:00    134.0
# Freq: T, dtype: float64

# %%
fig, ax = plt.subplots()
ax.grid(True)
ax.set_title("Tweet Frequencies")

hours = mdates.MinuteLocator(interval=1)
date_formatter = mdates.DateFormatter('%H:%M')

datemin = datetime(2016, 11, 12, 18, 37)
datemax = datetime(2016, 11, 12, 18, 47)

ax.xaxis.set_major_locator(hours)
ax.xaxis.set_major_formatter(date_formatter)
ax.set_xlim(datemin, datemax)
max_freq = per_minute.max()
ax.set_ylim(0, max_freq+100)
ax.plot(per_minute.index, per_minute)

#ax.xticks(rotation=90)

plt.savefig('tweet_time_series.png')

# %% [markdown]
# # [Extra] Users, Followers and Communities
#
# This section is not part of the assignment. Just read and play with it if you wanna learn a little bit of how to get users that are followers or friends of a certain node.

# %%
client = get_twitter_client()
profile = client.get_user(screen_name='ericinlinux')
print(json.dumps(profile._json, indent=4))
# Out:
# {
#     "follow_request_sent": false,
#     "has_extended_profile": false,
#     "profile_use_background_image": false,
#     "profile_text_color": "000000",
#     "default_profile_image": false,
#     "suspended": false,
#     "id": 40952530,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#     "verified": false,
#     "translator_type": "none",
#     "profile_location": null,
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1783085910/perfil1_normal.jpg",
#     "profile_sidebar_fill_color": "000000",
#     "entities": {
#         "url": {
#             "urls": [
#                 {
#                     "url": "http://t.co/Jl7Ny3Vh7Q",
#                     "indices": [
#                         0,
#                         22
#                     ],
#                     "expanded_url": "http://garotoreformado.blogspot.com",
#                     "display_url": "garotoreformado.blogspot.com"
#                 }
#             ]
#         },
#         "description": {
#             "urls": []
#         }
#     },
#     "followers_count": 358,
#     "profile_sidebar_border_color": "000000",
#     "id_str": "40952530",
#     "profile_background_color": "000000",
#     "needs_phone_verification": false,
#     "listed_count": 10,
#     "status": {
#         "contributors": null,
#         "truncated": true,
#         "text": "#NowListening A Lecture in Psychology: Religion, Morality, Evolution from Annual Reviews Conversations on\u2026 https://t.co/Ui9pKr5sPt",
#         "is_quote_status": false,
#         "in_reply_to_status_id": null,
#         "id": 929682200567648257,
#         "favorite_count": 0,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "retweeted": false,
#         "coordinates": null,
#         "entities": {
#             "symbols": [],
#             "user_mentions": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         0,
#                         13
#                     ],
#                     "text": "NowListening"
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/Ui9pKr5sPt",
#                     "indices": [
#                         107,
#                         130
#                     ],
#                     "expanded_url": "https://twitter.com/i/web/status/929682200567648257",
#                     "display_url": "twitter.com/i/web/status/9\u2026"
#                 }
#             ]
#         },
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "retweet_count": 0,
#         "id_str": "929682200567648257",
#         "favorited": false,
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "en",
#         "created_at": "Sun Nov 12 12:08:03 +0000 2017",
#         "in_reply_to_status_id_str": null,
#         "place": null
#     },
#     "is_translation_enabled": false,
#     "utc_offset": 3600,
#     "statuses_count": 2489,
#     "description": "AI researcher (PhD Candidate) @ VU Amsterdam. Interests on Social Contagion, Social Networks, Agent-based models, Python, Photography and Christian theology.",
#     "friends_count": 353,
#     "location": "Amsterdam, The Netherlands",
#     "profile_link_color": "FF691F",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1783085910/perfil1_normal.jpg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/40952530/1477484875",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#     "name": "Eric Ara\u00fajo",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 209,
#     "screen_name": "ericinlinux",
#     "notifications": false,
#     "url": "http://t.co/Jl7Ny3Vh7Q",
#     "created_at": "Mon May 18 19:55:45 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Amsterdam",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
# }

# %%
import time
import math

MAX_FRIENDS = 15000

def paginate(items, n):
    """Generate n-sized chunks from items"""
    for i in range(0, len(items), n):
        yield items[i:i+n]

# %%
screen_name = 'ericinlinux'

client = get_twitter_client()
dirname = "users/{}".format(screen_name)
max_pages = math.ceil(MAX_FRIENDS / 5000)

try:
    
    os.makedirs(dirname)
except OSError:
    print("Directory {} already exists".format(dirname))
except Exception as e:
    print("Error while creating directory {}".format(dirname))
    print(e)
    sys.exit(1)

# %%
# get followers for a given user
fname = "users/{}/followers.jsonl".format(screen_name)
with open(fname, 'w') as f:
    for followers in Cursor(client.followers_ids, screen_name=screen_name).pages(max_pages):
        for chunk in paginate(followers, 100):
            users = client.lookup_users(user_ids=chunk)
            for user in users:
                f.write(json.dumps(user._json)+"\n")
        if len(followers) == 5000:
            print("More results available. Sleeping for 60 seconds to avoid rate limit")
            time.sleep(60)

# get friends for a given user
fname = "users/{}/friends.jsonl".format(screen_name)
with open(fname, 'w') as f:
    for friends in Cursor(client.friends_ids, screen_name=screen_name).pages(max_pages):
        for chunk in paginate(friends, 100):
            users = client.lookup_users(user_ids=chunk)
            for user in users:
                f.write(json.dumps(user._json)+"\n")
        if len(friends) == 5000:
            print("More results available. Sleeping for 60 seconds to avoid rate limit")
            time.sleep(60)

# get user's profile
fname = "users/{}/user_profile.json".format(screen_name)
with open(fname, 'w') as f:
    profile = client.get_user(screen_name=screen_name)
    f.write(json.dumps(profile._json, indent=4))

# %% [markdown]
# You can see a folder called users in the same directory as this file with the json files there. You can try to extract information about the JSON files and get more from here.
#
# Have fun!
